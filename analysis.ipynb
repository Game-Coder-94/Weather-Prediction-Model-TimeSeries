# %% [markdown]
# ## Import Libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("datasets/1_Daily_minimum_temps.csv")
df.head()
# Out:
#        Date  Temp
# 0  01/01/81  20.7
# 1  01/02/81  17.9
# 2  01/03/81  18.8
# 3  01/04/81  14.6
# 4  01/05/81  15.8

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()

# %%
df_head = df[:50]
size = df_head["Temp"].size
x = np.linspace(0, 10, 50)

plt.figure(figsize=(15, 7))

plt.plot(df_head["Date"], df_head["Temp"])
plt.xticks(rotation=45)
plt.show()

# %%
df_head.shape, size
# Out:
# ((50, 2), 50)
